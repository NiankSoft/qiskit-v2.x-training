# %% [markdown]
# # Qiskit Developer Certification Exam
# ## Section 6: Use the estimator primitive
# ### Multiple Choice Questions (MCQ)
#
# ---
# **Instructions:** Each question has 4 options (A-D). Select the best answer. The correct answer with explanation is provided in the collapsed cell below each question.
#
# ---

# %% [markdown]
# ## Question 1
#
# [Task 6.2] What is Estimator designed to return?
#
# **A.** Raw measured bitstrings
# **B.** Only transpiler diagnostics
# **C.** Only runtime queue states
# **D.** Expectation value estimates for supplied observables

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Estimator targets expectation values of observables on prepared states.
#
# </details>

# %% [markdown]
# ---
# ## Question 2
#
# [Task 6.2] Why is observable-layout alignment a high-frequency exam trap?
#
# **A.** Wrong mapping yields numerically plausible but physically wrong expectations
# **B.** Layout never changes qubit mapping
# **C.** Alignment matters only for simulators
# **D.** Observables are ignored on hardware

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Transpilation can permute mapping; misaligned observables can silently produce wrong physics.
#
# </details>

# %% [markdown]
# ---
# ## Question 3
#
# [Task 6.2] Compared with Sampler, Estimator is naturally suited for:
#
# **A.** OpenQASM export
# **B.** Cost-function evaluation in VQE-like workflows
# **C.** Histogram plotting
# **D.** Queue monitoring

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Estimator is expectation-driven and central to variational cost evaluation.
#
# </details>

# %% [markdown]
# ---
# ## Question 4
#
# [Task 6.2] Tighter requested precision usually implies:
#
# **A.** Less sampling effort
# **B.** No effect
# **C.** Potentially more runtime/sampling effort
# **D.** Automatic qubit reduction

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Higher precision targets generally cost more computational/sampling resources.
#
# </details>

# %% [markdown]
# ---
# ## Question 5
#
# [Task 6.1] Which option name is commonly associated with high-level mitigation strength?
#
# **A.** `timing_level`
# **B.** `basis_level`
# **C.** `layout_level`
# **D.** `resilience_level`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# `resilience_level` is the common high-level mitigation control in Runtime Estimator workflows.
#
# </details>

# %% [markdown]
# ---
# ## Question 6
#
# [Task 6.1] Which statement is correct about mitigation tuning?
#
# **A.** Mitigation can improve robustness but often with overhead/tradeoffs
# **B.** Mitigation changes circuit logical function
# **C.** Higher mitigation is always superior regardless of cost
# **D.** Mitigation disables precision controls

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Tradeoff awareness is explicitly exam-relevant.
#
# </details>

# %% [markdown]
# ---
# ## Question 7
#
# [Task 6.2] What is a robust workflow ordering for Estimator jobs?
#
# **A.** Observables first, then random backend
# **B.** Build/transpile circuit, apply layout to observables, then run estimator
# **C.** Skip transpilation to preserve semantics
# **D.** Run sampler first to generate observables

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Observable mapping should reflect transpiled layout before Estimator execution.
#
# </details>

# %% [markdown]
# ---
# ## Question 8
#
# [Task 6.1] If precision is set both globally and per-run, expected precedence is usually:
#
# **A.** Backend ignores both
# **B.** They are multiplied
# **C.** More specific run/PUB precision typically takes precedence
# **D.** Global always overrides

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Precedence behavior is a frequent practical and test scenario.
#
# </details>

# %% [markdown]
# ---
# ## Question 9
#
# [Task 6.2] Which is the best interpretation of an Estimator output `ev`?
#
# **A.** Statevector amplitude
# **B.** Guaranteed exact eigenvalue
# **C.** Raw count fraction
# **D.** Estimated expectation value under chosen execution settings

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Estimator reports expectation estimates, which depend on execution/noise/precision settings.
#
# </details>

# %% [markdown]
# ---
# ## Question 10
#
# [Task 6.1/6.2] Which mistake most often causes silent scientific errors?
#
# **A.** Mismatched observables after transpilation/layout
# **B.** Using markdown comments
# **C.** Setting too many classical bits
# **D.** Calling draw() before run()

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Layout-observable mismatch can yield plausible but incorrect values.
#
# </details>

# %% [markdown]
# ---
# ## Question 11
#
# [Task 6.2] Which statement is true for parameterized Estimator workloads?
#
# **A.** Parameters force OpenQASM export
# **B.** Parameter sweeps can be submitted via supported input structures
# **C.** Parameters auto-bind to zero
# **D.** Parameters are unsupported

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Parameterized expectation sweeps are a core Estimator use-case.
#
# </details>

# %% [markdown]
# ---
# ## Question 12
#
# [Task 6.1] Practical tuning objective for Estimator is to:
#
# **A.** Use sampler defaults
# **B.** Maximize resilience and minimize precision unconditionally
# **C.** Balance precision/robustness/runtime for task goals
# **D.** Avoid all options

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Good configurations are objective-driven, not universally maximal.
#
# </details>

# %% [markdown]
# ---
# ## Question 13
#
# [Task 6.2] Why can two Estimator runs disagree slightly on same circuit/observable?
#
# **A.** Expectation values are always deterministic exact numbers
# **B.** Qiskit randomizes gate definitions
# **C.** Backend changes qubit count each run
# **D.** Finite sampling/noise/mitigation settings can shift estimates

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Run-to-run variation can occur due to finite resources and execution conditions.
#
# </details>

# %% [markdown]
# ---
# ## Question 14
#
# [Task 6.1] Which choice best captures exam intent around resilience?
#
# **A.** Understand high-level effect and tradeoffs of resilience settings
# **B.** Never use resilience
# **C.** Resilience replaces transpilation
# **D.** Know exact internal implementation details only

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Exam questions typically assess conceptual understanding of resilience impact.
#
# </details>

# %% [markdown]
# ---
# ## Question 15
#
# [Task 6.2] Estimator output should be interpreted with respect to:
#
# **A.** Only queue time
# **B.** The specific observable, mapping, and execution configuration
# **C.** Only circuit depth
# **D.** Only backend name

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Estimator values are meaningful only with full context of observable + execution settings.
#
# </details>

# %% [markdown]
# ---
# *End of Section 6 MCQ Practice - Keep pushing toward exam-day readiness.*
