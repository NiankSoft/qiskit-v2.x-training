# %% [markdown]
# # Qiskit Developer Certification Exam
# ## Blank Exam
#
# **Instructions:** Answers and explanations are included below each question.
#
# ---

# %% [markdown]
# ## Section 1: Pauli Operators and Quantum Operations

# %% [markdown]
# ## Question 1
#
# For a 2-qubit system in Qiskit, which Pauli label applies Z on qubit 1 and X on qubit 0?
#
# **A.** `'XZ'`
# **B.** `'ZX'`
# **C.** `'ZI'`
# **D.** `'IX'`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Qiskit Pauli strings are right-to-left by qubit index (rightmost char is qubit 0).
# So `Z` on qubit 1 and `X` on qubit 0 is `'ZX'`.
# - `'XZ'` would mean X on qubit 1 and Z on qubit 0.
#
# </details>

# %% [markdown]
# ---
# ## Question 2
#
# Which statement is correct for the commutator `[X, Z] = XZ - ZX`?
#
# **A.** `[X, Z] = 0`
# **B.** `[X, Z] = 2iY`
# **C.** `[X, Z] = -2iY`
# **D.** `[X, Z] = I`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Using Pauli algebra: `XZ = -iY` and `ZX = iY`, so `XZ - ZX = -2iY`.
# - **A** is false (they anti-commute).
# - **B** has the wrong sign.
# - **D** is unrelated.
#
# </details>

# %% [markdown]
# ---
# ## Question 3
#
# Consider:
#
# ```python
# qc = QuantumCircuit(1)
# qc.h(0)
# qc.z(0)
# qc.h(0)
# ```
#
# Which single-qubit gate is equivalent to this sequence (up to global phase)?
#
# **A.** Z
# **B.** X
# **C.** Y
# **D.** S

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Conjugation by H swaps X and Z axes: `H Z H = X`.
# This identity appears frequently in circuit simplification and basis-change questions.
#
# </details>

# %% [markdown]
# ---
# ## Question 4
#
# For the Bell state `|Phi+> = (|00> + |11>)/sqrt(2)`, what is `<XX>`?
#
# **A.** `-1`
# **B.** `0`
# **C.** `1`
# **D.** `0.5`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# `|Phi+>` is a +1 eigenstate of both `ZZ` and `XX`, so `<XX> = 1`.
# This is a standard two-qubit correlation property used in many exam questions.
#
# ```python
# from qiskit import QuantumCircuit
# from qiskit.quantum_info import Statevector, SparsePauliOp
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0, 1)
# sv = Statevector(qc)
# print(sv.expectation_value(SparsePauliOp('XX')).real)  # 1.0
# ```
#
# </details>

# %% [markdown]
# ---
# ## Question 5
#
# Which code correctly checks whether two operators are equivalent up to global phase?
#
# **A.** `op1 == op2`
# **B.** `op1.equiv(op2)`
# **C.** `op1.isclose(op2)`
# **D.** `op1 @ op2 == I`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# For Qiskit `Operator`, `.equiv(other)` checks equivalence up to global phase.
# Direct equality is stricter and usually fails when a global phase differs.
#
# </details>

# %% [markdown]
# ---
# ## Question 6
#
# What is the expectation value `<Y>` for state `|0>`?
#
# **A.** `1`
# **B.** `-1`
# **C.** `0`
# **D.** `i`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# `|0>` is an eigenstate of Z, not Y. Its Bloch vector is `(0, 0, 1)`, so `<Y> = 0`.
# Expectation values of Pauli operators are always real for valid quantum states.
#
# </details>

# %% [markdown]
# ---
# ## Question 7
#
# Given `P = Pauli('Y')`, which statement is true?
#
# **A.** `P` is unitary but not Hermitian
# **B.** `P` is Hermitian but not unitary
# **C.** `P` is both unitary and Hermitian
# **D.** `P` is neither unitary nor Hermitian

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# All Pauli matrices (X, Y, Z) are both Hermitian and unitary, and satisfy `P^2 = I`.
# This is a core property used in measurement and Hamiltonian contexts.
#
# </details>

# %% [markdown]
# ---
# ## Question 8
#
# Which `SparsePauliOp` expression is dimensionally valid for a 3-qubit Hamiltonian?
#
# **A.** `SparsePauliOp.from_list([('ZZ', 0.7), ('XII', 0.2)])`
# **B.** `SparsePauliOp.from_list([('ZIZ', 0.7), ('XII', 0.2)])`
# **C.** `SparsePauliOp.from_list([('Z', 0.7), ('XII', 0.2)])`
# **D.** `SparsePauliOp.from_list([('IIII', 1.0), ('XII', 0.2)])`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# All Pauli strings in one `SparsePauliOp` must have consistent length equal to qubit count.
# - **B** uses only 3-character strings.
# - **A** and **C** mix 2/1 with 3.
# - **D** mixes 4 with 3.
#
# </details>

# %% [markdown]
# ---
# ## Question 9
#
# Consider:
#
# ```python
# qc = QuantumCircuit(1)
# qc.y(0)
# qc.y(0)
# print(Statevector(qc))
# ```
#
# What is printed?
#
# **A.** `Statevector([1.+0.j, 0.+0.j])`
# **B.** `Statevector([-1.+0.j, 0.+0.j])`
# **C.** `Statevector([0.+0.j, 1.+0.j])`
# **D.** `Statevector([0.+1.j, 0.+0.j])`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Pauli-Y is self-inverse: `Y^2 = I`.
# Starting from `|0>`, two Y gates return `|0>`, giving `[1, 0]`.
#
# </details>

# %% [markdown]
# ---
# ## Question 10
#
# Which statement about global phase is correct in Qiskit operator comparisons?
#
# **A.** Two states/operators differing only by global phase represent different physical states
# **B.** Global phase can change measurement probabilities for a closed system
# **C.** `Operator.equiv` treats globally phased operators as equivalent
# **D.** Global phase only appears for multi-qubit states

# %% [markdown]
# ## Section 2: Visualize quantum circuits, measurements, and states

# %% [markdown]
# ## Question 11
#
# [Task 2.1] Which call renders a QuantumCircuit with Matplotlib?
#
# **A.** `qc.draw(output="mpl")`
# **B.** `qc.plot("mpl")`
# **C.** `plot_circuit(qc)`
# **D.** `qc.render("mpl")`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `QuantumCircuit.draw(output="mpl")` is the canonical API for Matplotlib circuit visualization.
#
# </details>

# %% [markdown]
# ---
# ## Question 12
#
# [Task 2.1] What does `idle_wires=False` do in circuit drawing?
#
# **A.** Reverses qubit order
# **B.** Hides wires with no operations
# **C.** Forces classical bits to the top
# **D.** Converts the circuit to DAG

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# It suppresses display of unused wires in the rendered diagram.
#
# </details>

# %% [markdown]
# ---
# ## Question 13
#
# [Task 2.1] What does `reverse_bits=True` change when drawing a circuit?
#
# **A.** The quantum state evolution
# **B.** Only displayed wire order
# **C.** The coupling map
# **D.** Measurement basis

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# It affects visual ordering only, not circuit semantics.
#
# </details>

# %% [markdown]
# ---
# ## Question 14
#
# [Task 2.2] Which function is used to visualize measurement counts as a bar chart?
#
# **A.** `plot_state_city`
# **B.** `plot_histogram`
# **C.** `plot_state_qsphere`
# **D.** `plot_bloch_multivector`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `plot_histogram` is the standard function for count distributions.
#
# </details>

# %% [markdown]
# ---
# ## Question 15
#
# [Task 2.2] How do you compare two count dictionaries on one histogram?
#
# **A.** `plot_histogram([c1, c2], legend=['Run 1', 'Run 2'])`
# **B.** `plot_histogram(c1 + c2)`
# **C.** `plot_state_city([c1, c2])`
# **D.** `plot_histogram(c1, c2, stacked=True)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Passing a list of count dictionaries with a legend is the standard comparison pattern.
#
# </details>

# %% [markdown]
# ---
# ## Question 16
#
# [Task 2.2] In `plot_histogram`, what does `sort='value_desc'` do?
#
# **A.** Sorts bars by key descending
# **B.** Sorts bars by count descending
# **C.** Sorts by Hamming weight
# **D.** Sorts by shot index

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `value_desc` orders outcomes by frequency from highest to lowest.
# Note that `desc` would orders outcomes by keys (label) from highest to lowest.
#
# </details>

# %% [markdown]
# ---
# ## Question 17
#
# [Task 2.3] Which function plots one Bloch sphere per qubit for a state?
#
# **A.** `plot_bloch_multivector`
# **B.** `plot_state_city`
# **C.** `plot_state_hinton`
# **D.** `plot_histogram`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `plot_bloch_multivector` gives per-qubit Bloch vectors.
#
# </details>

# %% [markdown]
# ---
# ## Question 18
#
# [Task 2.3] Which function emphasizes amplitudes/phases on a spherical basis-state layout?
#
# **A.** `plot_state_hinton`
# **B.** `plot_state_qsphere`
# **C.** `plot_distribution`
# **D.** `plot_gate_map`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Qsphere is designed to visualize basis-state amplitudes and phases.
#
# </details>

# %% [markdown]
# ---
# ## Question 19
#
# [Task 2.3] Which input type is appropriate for `plot_state_city`?
#
# **A.** Counts dictionary only
# **B.** State-like object or compatible array
# **C.** Backend object
# **D.** PassManager

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# State plots consume state information (e.g., statevector/density matrix), not counts.
#
# </details>

# %% [markdown]
# ---
# ## Question 20
#
# [Task 2.3] Which call correctly builds and visualizes a state on a qsphere?
#
# **A.** `plot_state_qsphere(Statevector.from_instruction(qc))`
# **B.** `plot_state_qsphere(qc.draw())`
# **C.** `plot_state_qsphere(result.get_counts())`
# **D.** `plot_state_qsphere(backend)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Construct a state object from the circuit and pass it to `plot_state_qsphere`.
#
# </details>

# %% [markdown]
# ## Section 3: Create quantum circuits

# %% [markdown]
# ## Question 21
#
# [Task 3.1] Which construct is used for classical-condition branching in a dynamic circuit?
#
# **A.** `with qc.if_test((c, 1)):`
# **B.** `with qc.if(c == 1):`
# **C.** `if c == 1: qc.x(0)`
# **D.** `qc.c_if_block(c, 1)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `if_test` is the control-flow context manager used in dynamic circuits.
#
# </details>

# %% [markdown]
# ---
# ## Question 22
#
# [Task 3.1] Which control-flow construct supports repeated execution while a condition holds?
#
# **A.** `for_loop`
# **B.** `while_loop`
# **C.** `repeat`
# **D.** `loop_if`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `while_loop` is the dedicated dynamic-circuit loop construct.
#
# </details>

# %% [markdown]
# ---
# ## Question 23
#
# [Task 3.1] A `for_loop(range(4))` in Qiskit represents:
#
# **A.** Only Python-side code expansion
# **B.** A control-flow operation in circuit representation
# **C.** A transpiler optimization
# **D.** A backend calibration step

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# It is represented as circuit control flow rather than plain Python duplication.
#
# </details>

# %% [markdown]
# ---
# ## Question 24
#
# [Task 3.2] Which class is intended for a vector of symbolic parameters?
#
# **A.** `ParameterArray`
# **B.** `ParameterVector`
# **C.** `ParameterList`
# **D.** `ParameterSet`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `ParameterVector` is the standard Qiskit helper for indexed symbolic parameters.
#
# </details>

# %% [markdown]
# ---
# ## Question 25
#
# [Task 3.2] Which call returns a NEW circuit with assigned parameter values?
#
# **A.** `qc.assign_parameters({theta: 0.2}, inplace=False)`
# **B.** `qc.assign_parameters({theta: 0.2}, inplace=True)`
# **C.** `qc.set_parameter(theta, 0.2)`
# **D.** `theta.assign(qc, 0.2)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `inplace=False` returns a new circuit; `inplace=True` mutates the existing one.
#
# </details>

# %% [markdown]
# ---
# ## Question 26
#
# [Task 3.2] Why are symbolic parameters useful?
#
# **A.** They eliminate transpilation
# **B.** They allow reusable circuit templates and parameter sweeps
# **C.** They force deterministic measurements
# **D.** They increase qubit count

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Parameters let one circuit structure be reused across many values.
#
# </details>

# %% [markdown]
# ---
# ## Question 27
#
# [Task 3.3] Which transpile call applies the highest built-in optimization level?
#
# **A.** `transpile(qc, backend, optimization_level=3)`
# **B.** `transpile(qc, backend, optimization_level=1)`
# **C.** `qc.transpile(backend, level=3)`
# **D.** `backend.optimize(qc, 3)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Optimization level 3 is the most aggressive preset level.
#
# </details>

# %% [markdown]
# ---
# ## Question 28
#
# [Task 3.3] Which helper builds a preset pass manager for a backend?
#
# **A.** `generate_preset_pass_manager(backend=backend, optimization_level=2)`
# **B.** `PassManager.preset(backend)`
# **C.** `backend.pass_manager()`
# **D.** `build_passes(backend)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `generate_preset_pass_manager` is the official API for preset transpiler pipelines.
#
# </details>

# %% [markdown]
# ---
# ## Question 29
#
# [Task 3.3] How is that pass manager typically executed on a circuit?
#
# **A.** `pm.execute(qc)`
# **B.** `pm.run(qc)`
# **C.** `pm.transpile(qc)`
# **D.** `pm.apply(qc)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Pass managers are applied with `run(...)`.
#
# </details>

# %% [markdown]
# ---
# ## Question 30
#
# [Task 3.4] Which pattern creates a Bell pair from `|00>`?
#
# **A.** `qc.h(0); qc.cx(0, 1)`
# **B.** `qc.cx(0, 1); qc.h(1)`
# **C.** `qc.h(1); qc.cx(0, 1)`
# **D.** `qc.x(0); qc.z(1)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Hadamard on qubit 0 then CX(0,1) creates a Bell-state preparation circuit.
#
# </details>

# %% [markdown]
# ---
# ## Question 31
#
# [Task 3.4] What does `qc.measure_all()` do?
#
# **A.** Measures only qubit 0
# **B.** Adds measurements for all qubits
# **C.** Resets all qubits
# **D.** Creates a density matrix

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# It inserts measurement operations for all qubits.
#
# </details>

# %% [markdown]
# ---
# ## Question 32
#
# [Task 3.4] Which is the correct way to append a gate `g` to qubits 0 and 1?
#
# **A.** `qc.append(g, [0, 1])`
# **B.** `qc.add_gate(g, [0, 1])`
# **C.** `qc.push(g, [0, 1])`
# **D.** `qc.insert(g, [0, 1])`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# `append` is the standard API for adding a gate/instruction to qubits.
#
# </details>

# %% [markdown]
# ---
# ## Question 33
#
# [Task 3.1] Which statement about dynamic circuits is true?
#
# **A.** They cannot include measurement
# **B.** They support classical-conditional control flow
# **C.** They only run in OpenQASM 2
# **D.** They cannot be transpiled

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Dynamic circuits include runtime classical conditions/loops.
#
# </details>

# %% [markdown]
# ---
# ## Question 34
#
# [Task 3.2] After fully binding all parameters, `qc.parameters` is typically:
#
# **A.** Unchanged
# **B.** Empty
# **C.** Converted to classical bits
# **D.** A list of floats

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Fully bound circuits no longer expose free symbolic parameters.
#
# </details>

# %% [markdown]
# ---
# ## Question 35
#
# [Task 3.3] Why transpile before hardware execution?
#
# **A.** To increase circuit width
# **B.** To match backend gate set/connectivity constraints
# **C.** To remove all measurements
# **D.** To bypass mapping

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Transpilation produces ISA-compatible circuits for the target backend.
#
# </details>

# %% [markdown]
# ## Section 4: Run quantum circuits

# %% [markdown]
# ## Question 36
#
# [Task 4.1] What is the main purpose of a Runtime Session?
#
# **A.** Replacing transpilation
# **B.** Avoiding authentication
# **C.** Grouping iterative jobs with reduced queue overhead
# **D.** Storing plots

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Sessions are designed to support iterative workflows with better scheduling behavior.
#
# </details>

# %% [markdown]
# ---
# ## Question 37
#
# [Task 4.1] What usually happens after calling `session.close()`?
#
# **A.** Backend is reset
# **B.** All prior results are deleted
# **C.** Jobs are converted to local simulation
# **D.** New jobs are no longer accepted; existing jobs may complete

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Closing a session typically blocks new submissions while allowing in-flight work to finish.
#
# </details>

# %% [markdown]
# ---
# ## Question 38
#
# [Task 4.1] Which execution mode is intended for grouped queued workloads?
#
# **A.** Debug
# **B.** Batch
# **C.** Preview
# **D.** Offline

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Batch mode is intended for grouped, queued job execution.
#
# </details>

# %% [markdown]
# ---
# ## Question 39
#
# [Task 4.1] Execution mode selection primarily affects:
#
# **A.** Scheduling/queueing semantics
# **B.** Number of qubits in the backend
# **C.** Circuit algebra
# **D.** Classical register width

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Modes change how jobs are scheduled and managed, not circuit mathematics.
#
# </details>

# %% [markdown]
# ---
# ## Question 40
#
# [Task 4.1] For iterative hybrid algorithms, the common recommended mode is:
#
# **A.** OpenQASM-only execution
# **B.** REST-only direct calls
# **C.** Independent one-off jobs only
# **D.** Session-based workflow

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Sessions fit iterative loops common in hybrid algorithms.
#
# </details>

# %% [markdown]
# ---
# ## Question 41
#
# [Task 4.2] In Sampler workflows, where can shots be specified?
#
# **A.** Nowhere
# **B.** Only backend defaults
# **C.** At run-level and/or per input payload depending API
# **D.** Only constructor

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Shots can be configured in execution calls and/or payload structures.
#
# </details>

# %% [markdown]
# ---
# ## Question 42
#
# [Task 4.2] In primitives context, a PUB is best understood as:
#
# **A.** A single primitive input unit
# **B.** A queue position token
# **C.** A backend calibration blob
# **D.** A transpiler pass set

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# PUB is the atomic input block used by primitive interfaces.
#
# </details>

# %% [markdown]
# ---
# ## Question 43
#
# [Task 4.2] Why is broadcasting useful with primitives?
#
# **A.** It removes transpilation
# **B.** It disables mitigation
# **C.** It changes topology
# **D.** It efficiently evaluates multiple parameter/observable combinations

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Broadcasting reduces manual looping for sweeps/combinations.
#
# </details>

# %% [markdown]
# ---
# ## Question 44
#
# [Task 4.2] Before hardware primitive execution, you should ensure:
#
# **A.** Backend has exactly 2 qubits
# **B.** Circuit and related objects are backend-compatible after transpilation/layout mapping
# **C.** All parameters are integers
# **D.** No measurements in any circuit

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Hardware runs require ISA and mapping compatibility.
#
# </details>

# %% [markdown]
# ---
# ## Question 45
#
# [Task 4.2] Which statement is correct?
#
# **A.** Primitives bypass job lifecycle
# **B.** Primitives always return raw counts dicts
# **C.** Primitives integrate with runtime execution modes
# **D.** Primitives cannot run in sessions

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Primitives are designed to work with runtime modes such as sessions/batches.
#
# </details>

# %% [markdown]
# ## Section 5: Use the sampler primitive

# %% [markdown]
# ## Question 46[Task 5.2] What does Sampler fundamentally return for measured circuits?**A.** Sampled outcomes / distributions from measurements    **B.** Backend calibration snapshots    **C.** Expectation values of observables    **D.** Unitary decomposition diagnostics

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Sampler is for sampling measurement outcomes, not direct expectation-value estimation.</details>

# %% [markdown]
# ---## Question 47[Task 5.2] Which statement best contrasts Sampler vs Estimator?**A.** Estimator always returns counts    **B.** Sampler returns sampling data, Estimator returns expectation estimates    **C.** Sampler cannot run on hardware    **D.** Sampler requires observables and returns evs

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Sampler is distribution-centric; Estimator is observable-expectation-centric.</details>

# %% [markdown]
# ---## Question 48[Task 5.2] If shots increase from 1k to 16k, what typically changes?**A.** Statistical uncertainty in sampled frequencies decreases    **B.** Backend coupling map changes    **C.** Measurement basis is redefined    **D.** Gate semantics change

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Higher shots reduce sampling variance in estimated frequencies.</details>

# %% [markdown]
# ---## Question 49[Task 5.2] In modern primitive APIs, a common source of mistakes is confusing:**A.** Qubit indices and classical bits only    **B.** Backend names and provider names    **C.** Quantum and classical registers    **D.** Per-run settings vs per-PUB settings

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Many exam traps target precedence between global/run-level and per-input configuration.</details>

# %% [markdown]
# ---## Question 50[Task 5.2] Which result-access mindset is safest for multi-input runs?**A.** Only parse logs    **B.** Assume one flat dictionary always    **C.** Use transpiler metadata as final output    **D.** Treat results as structured per submitted input block

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Sampler outputs are structured; robust code indexes by submission/result blocks.</details>

# %% [markdown]
# ---## Question 51[Task 5.1] Why can twirling be useful in sampling workflows?**A.** It guarantees exact noiseless results    **B.** It forces deterministic bitstrings    **C.** It removes need for transpilation    **D.** It can convert coherent error signatures into more stochastic-like behavior

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Twirling is an error-shaping strategy, not a guarantee of perfect accuracy.</details>

# %% [markdown]
# ---## Question 52[Task 5.1] Which is the most exam-relevant tradeoff statement?**A.** Shots and options are independent concepts    **B.** Robustness options are always free    **C.** Twirling always reduces variance    **D.** Robustness options can improve quality but may increase runtime/cost

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Certification questions often test understanding of quality-cost tradeoffs.</details>

# %% [markdown]
# ---## Question 53[Task 5.1] If option defaults and run-time values conflict, what is usually expected?**A.** Defaults always win    **B.** All settings are averaged    **C.** More specific run/PUB settings typically override broader defaults    **D.** Backend silently rejects all options

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Specificity precedence is a recurring practical and exam concept.</details>

# %% [markdown]
# ---## Question 54[Task 5.1] Which is a reliable configuration approach in practice?**A.** Set everything to max by default    **B.** Never use options    **C.** Tune shots + options to algorithm tolerance and budget    **D.** Copy Estimator settings blindly

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Sampler tuning should be goal-driven and resource-aware.</details>

# %% [markdown]
# ---## Question 55[Task 5.2] A common trap: interpreting Sampler output as exact probabilities. Correct view?**A.** Always exact by definition    **B.** Finite-shot estimates with sampling error unless idealized/infinite    **C.** Equivalent to statevector amplitudes    **D.** Independent of shot count

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Sampler outputs are empirical estimates unless in idealized simulation settings.</details>

# %% [markdown]
# ---## Question 56[Task 5.2] If a circuit has no measurements, sampler behavior is best described as:**A.** Automatically inserts observables    **B.** Always valid and meaningful bitstring output    **C.** Measurement outcomes are undefined without a measurement mapping    **D.** Equivalent to estimator

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Sampler semantics revolve around measured outcomes; measurement mapping matters.</details>

# %% [markdown]
# ---## Question 57[Task 5.1] Which statement about dynamical decoupling (DD) is correct?**A.** DD only works for classical simulators    **B.** DD is an execution/noise-handling strategy and may affect runtime overhead    **C.** DD replaces shot settings    **D.** DD changes circuit algorithm semantics by definition

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  DD is an execution strategy for noise behavior, with practical overhead considerations.</details>

# %% [markdown]
# ---## Question 58[Task 5.2] When comparing two sampler runs, best practice is to:**A.** Use same or controlled shot settings and inspect distribution differences    **B.** Compare only most frequent bitstring    **C.** Ignore metadata    **D.** Assume any difference is backend bug

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Fair comparisons require controlled settings and distribution-level analysis.</details>

# %% [markdown]
# ---## Question 59[Task 5.1/5.2] Which statement is true?**A.** Sampler output format is unrelated to primitive input structure    **B.** Sampler always returns one scalar    **C.** Input structure and parameter broadcasting affect output organization    **D.** Sampler cannot handle parameterized circuits

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Input payload structure drives how outputs are grouped and interpreted.</details>

# %% [markdown]
# ---## Question 60[Task 5.2] Why is Sampler a good fit for classification-like readout tasks?**A.** It directly estimates outcome probabilities/frequencies    **B.** It replaces transpilation    **C.** It gives direct ev gradients    **D.** It avoids hardware queueing

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Sampler directly provides measurement statistics that such tasks consume.</details>

# %% [markdown]
# ## Section 6: Use the estimator primitive

# %% [markdown]
# ## Question 61[Task 6.2] What is Estimator designed to return?**A.** Only transpiler diagnostics    **B.** Only runtime queue states    **C.** Expectation value estimates for supplied observables    **D.** Raw measured bitstrings

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Estimator targets expectation values of observables on prepared states.</details>

# %% [markdown]
# ---## Question 62[Task 6.2] Why is observable-layout alignment a high-frequency exam trap?**A.** Alignment matters only for simulators    **B.** Wrong mapping yields numerically plausible but physically wrong expectations    **C.** Layout never changes qubit mapping    **D.** Observables are ignored on hardware

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Transpilation can permute mapping; misaligned observables can silently produce wrong physics.</details>

# %% [markdown]
# ---## Question 63[Task 6.2] Compared with Sampler, Estimator is naturally suited for:**A.** Queue monitoring    **B.** Histogram plotting    **C.** Cost-function evaluation in VQE-like workflows    **D.** OpenQASM export

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Estimator is expectation-driven and central to variational cost evaluation.</details>

# %% [markdown]
# ---## Question 64[Task 6.2] Tighter requested precision usually implies:**A.** Less sampling effort    **B.** No effect    **C.** Potentially more runtime/sampling effort    **D.** Automatic qubit reduction

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Higher precision targets generally cost more computational/sampling resources.</details>

# %% [markdown]
# ---## Question 65[Task 6.1] Which option name is commonly associated with high-level mitigation strength?**A.** `timing_level`    **B.** `resilience_level`    **C.** `basis_level`    **D.** `layout_level`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  `resilience_level` is the common high-level mitigation control in Runtime Estimator workflows.</details>

# %% [markdown]
# ---## Question 66[Task 6.1] Which statement is correct about mitigation tuning?**A.** Mitigation can improve robustness but often with overhead/tradeoffs    **B.** Mitigation disables precision controls    **C.** Higher mitigation is always superior regardless of cost    **D.** Mitigation changes circuit logical function

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Tradeoff awareness is explicitly exam-relevant.</details>

# %% [markdown]
# ---## Question 67[Task 6.2] What is a robust workflow ordering for Estimator jobs?**A.** Observables first, then random backend    **B.** Run sampler first to generate observables    **C.** Skip transpilation to preserve semantics    **D.** Build/transpile circuit, apply layout to observables, then run estimator

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Observable mapping should reflect transpiled layout before Estimator execution.</details>

# %% [markdown]
# ---## Question 68[Task 6.1] If precision is set both globally and per-run, expected precedence is usually:**A.** They are multiplied    **B.** More specific run/PUB precision typically takes precedence    **C.** Global always overrides    **D.** Backend ignores both

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Precedence behavior is a frequent practical and test scenario.</details>

# %% [markdown]
# ---## Question 69[Task 6.2] Which is the best interpretation of an Estimator output `ev`?**A.** Statevector amplitude    **B.** Estimated expectation value under chosen execution settings    **C.** Raw count fraction    **D.** Guaranteed exact eigenvalue

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Estimator reports expectation estimates, which depend on execution/noise/precision settings.</details>

# %% [markdown]
# ---## Question 70[Task 6.1/6.2] Which mistake most often causes silent scientific errors?**A.** Calling draw() before run()    **B.** Using markdown comments    **C.** Setting too many classical bits    **D.** Mismatched observables after transpilation/layout

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Layout-observable mismatch can yield plausible but incorrect values.</details>

# %% [markdown]
# ---## Question 71[Task 6.2] Which statement is true for parameterized Estimator workloads?**A.** Parameter sweeps can be submitted via supported input structures    **B.** Parameters are unsupported    **C.** Parameters auto-bind to zero    **D.** Parameters force OpenQASM export

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Parameterized expectation sweeps are a core Estimator use-case.</details>

# %% [markdown]
# ---## Question 72[Task 6.1] Practical tuning objective for Estimator is to:**A.** Balance precision/robustness/runtime for task goals    **B.** Use sampler defaults    **C.** Avoid all options    **D.** Maximize resilience and minimize precision unconditionally

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Good configurations are objective-driven, not universally maximal.</details>

# %% [markdown]
# ---## Question 73[Task 6.2] Why can two Estimator runs disagree slightly on same circuit/observable?**A.** Expectation values are always deterministic exact numbers    **B.** Qiskit randomizes gate definitions    **C.** Backend changes qubit count each run    **D.** Finite sampling/noise/mitigation settings can shift estimates

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Run-to-run variation can occur due to finite resources and execution conditions.</details>

# %% [markdown]
# ---## Question 74[Task 6.1] Which choice best captures exam intent around resilience?**A.** Resilience replaces transpilation    **B.** Know exact internal implementation details only    **C.** Never use resilience    **D.** Understand high-level effect and tradeoffs of resilience settings

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Exam questions typically assess conceptual understanding of resilience impact.</details>

# %% [markdown]
# ---## Question 75[Task 6.2] Estimator output should be interpreted with respect to:**A.** The specific observable, mapping, and execution configuration    **B.** Only backend name    **C.** Only circuit depth    **D.** Only queue time

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Estimator values are meaningful only with full context of observable + execution settings.</details>

# %% [markdown]
# ## Section 7: Retrieve and analyze the results of quantum circuits

# %% [markdown]
# ## Question 76[Task 7.1] Which call pattern is commonly used to retrieve jobs for a session id?**A.** `service.jobs(filter=sid)`    **B.** `Session.jobs(sid)`    **C.** `service.jobs(session_id=sid)`    **D.** `service.get_session_jobs(sid)`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Filtering by `session_id` is the common retrieval workflow in Runtime services.</details>

# %% [markdown]
# ---## Question 77[Task 7.1] Which method generally blocks until completion and returns the payload?**A.** `job.result()`    **B.** `job.metrics()`    **C.** `job.status()`    **D.** `job.wait_queue()`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  `result()` is the standard blocking accessor for job output.</details>

# %% [markdown]
# ---## Question 78[Task 7.2] Which status most directly indicates active execution?**A.** `QUEUED`    **B.** `RUNNING`    **C.** `CANCELLED`    **D.** `INITIALIZING`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  `RUNNING` indicates the job is being executed.</details>

# %% [markdown]
# ---## Question 79[Task 7.2] A robust polling loop should primarily watch:**A.** Circuit draw output    **B.** Notebook kernel messages    **C.** Job status transitions until terminal state    **D.** Qubit labels

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Operational monitoring should follow lifecycle status transitions.</details>

# %% [markdown]
# ---## Question 80[Task 7.2] What is the practical role of `cancel()`?**A.** Reset backend calibration    **B.** Force successful result creation    **C.** Delete all account jobs    **D.** Request stop/cancellation depending current state

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Cancellation is a lifecycle operation whose effect depends on current progress.</details>

# %% [markdown]
# ---## Question 81[Task 7.1] Why are Runtime decoders/encoders used with `json` persistence?**A.** To preserve structured result objects through serialization    **B.** To reduce shot counts    **C.** To alter numeric precision    **D.** To bypass auth

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  They preserve Runtime object structure across storage and reload.</details>

# %% [markdown]
# ---## Question 82[Task 7.1] For multi-input primitive jobs, safest result interpretation is:**A.** Assume one scalar output    **B.** Ignore metadata    **C.** Use first value only    **D.** Index/analyze outputs per input block

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Result structure follows submission structure; per-block analysis is required.</details>

# %% [markdown]
# ---## Question 83[Task 7.2] Why monitor queue position and runtime metrics?**A.** To change backend topology    **B.** To estimate delays and diagnose operational bottlenecks    **C.** Only for dashboards    **D.** To rewrite circuits

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  These signals support scheduling expectations and troubleshooting.</details>

# %% [markdown]
# ---## Question 84[Task 7.2] If `result()` throws a failure exception, first action should be:**A.** Inspect job status/error details/logs    **B.** Rerun blindly many times    **C.** Change visualization style    **D.** Delete session immediately

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Diagnosis begins with explicit error/status context.</details>

# %% [markdown]
# ---## Question 85[Task 7.1] Historical result retrieval is generally possible via:**A.** Only current notebook memory    **B.** Only transpiler cache    **C.** Only backend local files    **D.** Service-level query/filter APIs

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Runtime services typically expose query mechanisms for past jobs.</details>

# %% [markdown]
# ---## Question 86[Task 7.2] Which statement is true about terminal states?**A.** DONE/CANCELLED/ERROR-like states are terminal categories    **B.** RUNNING is terminal    **C.** Only SUCCESS is terminal    **D.** QUEUED is terminal

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Terminal lifecycle includes multiple non-running end states.</details>

# %% [markdown]
# ---## Question 87[Task 7.1] In production analyses, why keep job metadata with results?**A.** Metadata replaces results    **B.** Metadata changes outcomes    **C.** Context (settings/backend/timestamps) is essential for interpretation    **D.** Metadata is irrelevant

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Reproducible interpretation requires contextual metadata.</details>

# %% [markdown]
# ---## Question 88[Task 7.2] A subtle but critical bug is:**A.** Drawing circuits before run    **B.** Printing status too often    **C.** Mixing up results from different job ids/session ids    **D.** Using markdown in notebooks

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Cross-job/session mixups can silently corrupt analysis conclusions.</details>

# %% [markdown]
# ---## Question 89[Task 7.1/7.2] What is a good retrieval strategy under intermittent API/network issues?**A.** No retries ever    **B.** Controlled retry with status re-check and idempotent retrieval logic    **C.** Submit duplicate jobs each retry    **D.** Ignore failures

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Robust clients combine retries with explicit job-id/status checks.</details>

# %% [markdown]
# ---## Question 90[Task 7.2] Which is true about monitoring intervals?**A.** Never poll    **B.** Use reasonable polling intervals to balance responsiveness and API load    **C.** Poll only after completion    **D.** Poll as fast as possible always

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Practical monitoring balances latency and API efficiency.</details>

# %% [markdown]
# ## Section 8: Operate with OpenQASM

# %% [markdown]
# ## Question 91[Task 8.1] Which API exports a circuit to OpenQASM 3 text in Qiskit?**A.** `qc.qasm3()`    **B.** `qc.to_qasm3_text()`    **C.** `qiskit.qasm.dumps(qc)`    **D.** `qiskit.qasm3.dumps(qc)`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  `qiskit.qasm3.dumps` is the canonical QASM3 text exporter.</details>

# %% [markdown]
# ---## Question 92[Task 8.1] Which statement about OpenQASM 3 classical typing is correct?**A.** Types are comments only    **B.** Only float arrays exist    **C.** It supports typed classical constructs (bit/int/uint/angle, etc.)    **D.** No classical typing exists

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  OpenQASM 3 adds richer typed classical language features.</details>

# %% [markdown]
# ---## Question 93[Task 8.2] A key semantic distinction of OpenQASM 3 vs 2 is:**A.** Richer control-flow and classical semantics    **B.** No interoperability    **C.** No measurements    **D.** No quantum gates

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  OpenQASM 3 extends program semantics beyond OpenQASM 2's simpler model.</details>

# %% [markdown]
# ---## Question 94[Task 8.2] Why is semantic understanding exam-critical?**A.** Semantics are ignored by compilers    **B.** Syntax alone determines runtime behavior    **C.** Semantics only matter for REST    **D.** Correct behavior depends on language semantics, not just syntax shape

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Many traps involve syntactically valid but semantically different constructs.</details>

# %% [markdown]
# ---## Question 95[Task 8.3] Which interop statement is accurate?**A.** Interop requires non-Python tooling only    **B.** QASM2/QASM3 interop is impossible    **C.** Interop exists, but round-trip fidelity may depend on feature support    **D.** Round-trip is always exact for all constructs

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Interop is supported with practical limitations for unsupported constructs.</details>

# %% [markdown]
# ---## Question 96[Task 8.3] If loader/parser meets unsupported OpenQASM feature, likely outcome is:**A.** Silent automatic fallback always    **B.** Guaranteed equivalent rewrite    **C.** Import/parse failure    **D.** Backend hardware reset

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Unsupported features typically fail at parse/import stage.</details>

# %% [markdown]
# ---## Question 97[Task 8.3] Common workflow where supported:**A.** `QuantumCircuit -> qasm3.dumps -> qasm3.loads`    **B.** `backend.run -> dumps only`    **C.** `qasm2.dumps -> transpile -> histogram`    **D.** `loads` requires pulse schedule

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  QASM3 export/import APIs form a direct conversion workflow.</details>

# %% [markdown]
# ---## Question 98[Task 8.4] Which HTTP method is typically used for creating/submitting Runtime jobs?**A.** GET    **B.** DELETE    **C.** PATCH    **D.** POST

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Creation/submission endpoints generally use POST semantics.</details>

# %% [markdown]
# ---## Question 99[Task 8.4] Which cancellation endpoint style is typically expected?**A.** `PATCH /v1/cancel/{id}`    **B.** `POST /v1/jobs/{id}/cancel`    **C.** `GET /v1/jobs/{id}/cancel`    **D.** `DELETE /v1/jobs/cancel/{id}`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Cancellation is commonly modeled as an action endpoint on a job resource.</details>

# %% [markdown]
# ---## Question 100[Task 8.4] Standard auth header pattern for IBM-style runtime APIs is:**A.** `Token <value>`    **B.** `Bearer <token>`    **C.** `Session <id>`    **D.** `Runtime <token>`

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Bearer token authentication is the usual pattern.</details>

# %% [markdown]
# ---## Question 101[Task 8.4] Why do API versioned paths matter (`/v1/...`)?**A.** They disable auth requirements    **B.** They set backend shots    **C.** They enforce session mode    **D.** They define contract/version compatibility boundaries

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: D****Explanation:**  Versioned routes communicate stable API contracts over time.</details>

# %% [markdown]
# ---## Question 102[Task 8.4] In client polling logic, safest control variable is:**A.** Notebook execution counter    **B.** Circuit depth    **C.** Job status transitions until terminal state    **D.** Register names

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: C****Explanation:**  Reliable orchestration should follow job lifecycle status transitions.</details>

# %% [markdown]
# ---## Question 103[Task 8.1] Which statement is true about OpenQASM 3 includes/gate declarations?**A.** Includes auto-execute jobs    **B.** Includes/declarations provide reusable language-level definitions    **C.** Includes replace transpilation    **D.** Includes are forbidden

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  Includes and declarations are language constructs for reusable definitions/context.</details>

# %% [markdown]
# ---## Question 104[Task 8.2] Measurement in OpenQASM semantics maps quantum data to:**A.** Classical data    **B.** Another qubit    **C.** A pass manager    **D.** A backend layout

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: A****Explanation:**  Measurement produces classical outcomes.</details>

# %% [markdown]
# ---## Question 105[Task 8.1/8.2] Which statement is correct?**A.** OpenQASM 3 is only a diagram format    **B.** OpenQASM 3 is a language for quantum-classical programs    **C.** OpenQASM 3 requires hardware-only execution    **D.** OpenQASM 3 cannot represent control flow

# %% [markdown]
# <details><summary>Click to reveal Answer & Explanation</summary>**Correct Answer: B****Explanation:**  It is a full language representation with syntax and semantics.</details>
