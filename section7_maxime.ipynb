# %% [markdown]
# # Qiskit Developer Certification Exam
# ## Section 7: Retrieve and analyze the results of quantum circuits
# ### Multiple Choice Questions (MCQ)
#
# ---
# **Instructions:** Each question has 4 options (A-D). Select the best answer. The correct answer with explanation is provided in the collapsed cell below each question.
#
# ---

# %% [markdown]
# ## Question 1
#
# [Task 7.1] Which call pattern is commonly used to retrieve jobs for a session id?
#
# **A.** `service.jobs(session_id=sid)`
# **B.** `service.get_session_jobs(sid)`
# **C.** `Session.jobs(sid)`
# **D.** `service.jobs(filter=sid)`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Filtering by `session_id` is the common retrieval workflow in Runtime services.
#
# </details>

# %% [markdown]
# ---
# ## Question 2
#
# [Task 7.1] Which method generally blocks until completion and returns the payload?
#
# **A.** `job.wait_queue()`
# **B.** `job.result()`
# **C.** `job.metrics()`
# **D.** `job.status()`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `result()` is the standard blocking accessor for job output.
#
# </details>

# %% [markdown]
# ---
# ## Question 3
#
# [Task 7.2] Which status most directly indicates active execution?
#
# **A.** `CANCELLED`
# **B.** `QUEUED`
# **C.** `RUNNING`
# **D.** `INITIALIZING`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# `RUNNING` indicates the job is being executed.
#
# </details>

# %% [markdown]
# ---
# ## Question 4
#
# [Task 7.2] A robust polling loop should primarily watch:
#
# **A.** Notebook kernel messages
# **B.** Circuit draw output
# **C.** Qubit labels
# **D.** Job status transitions until terminal state

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Operational monitoring should follow lifecycle status transitions.
#
# </details>

# %% [markdown]
# ---
# ## Question 5
#
# [Task 7.2] What is the practical role of `cancel()`?
#
# **A.** Request stop/cancellation depending current state
# **B.** Delete all account jobs
# **C.** Reset backend calibration
# **D.** Force successful result creation

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Cancellation is a lifecycle operation whose effect depends on current progress.
#
# </details>

# %% [markdown]
# ---
# ## Question 6
#
# [Task 7.1] Why are Runtime decoders/encoders used with `json` persistence?
#
# **A.** To bypass auth
# **B.** To preserve structured result objects through serialization
# **C.** To alter numeric precision
# **D.** To reduce shot counts

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# They preserve Runtime object structure across storage and reload.
#
# </details>

# %% [markdown]
# ---
# ## Question 7
#
# [Task 7.1] For multi-input primitive jobs, safest result interpretation is:
#
# **A.** Assume one scalar output
# **B.** Use first value only
# **C.** Index/analyze outputs per input block
# **D.** Ignore metadata

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Result structure follows submission structure; per-block analysis is required.
#
# </details>

# %% [markdown]
# ---
# ## Question 8
#
# [Task 7.2] Why monitor queue position and runtime metrics?
#
# **A.** To rewrite circuits
# **B.** To change backend topology
# **C.** Only for dashboards
# **D.** To estimate delays and diagnose operational bottlenecks

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# These signals support scheduling expectations and troubleshooting.
#
# </details>

# %% [markdown]
# ---
# ## Question 9
#
# [Task 7.2] If `result()` throws a failure exception, first action should be:
#
# **A.** Inspect job status/error details/logs
# **B.** Change visualization style
# **C.** Rerun blindly many times
# **D.** Delete session immediately

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Diagnosis begins with explicit error/status context.
#
# </details>

# %% [markdown]
# ---
# ## Question 10
#
# [Task 7.1] Historical result retrieval is generally possible via:
#
# **A.** Only current notebook memory
# **B.** Service-level query/filter APIs
# **C.** Only transpiler cache
# **D.** Only backend local files

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Runtime services typically expose query mechanisms for past jobs.
#
# </details>

# %% [markdown]
# ---
# ## Question 11
#
# [Task 7.2] Which statement is true about terminal states?
#
# **A.** RUNNING is terminal
# **B.** QUEUED is terminal
# **C.** DONE/CANCELLED/ERROR-like states are terminal categories
# **D.** Only SUCCESS is terminal

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Terminal lifecycle includes multiple non-running end states.
#
# </details>

# %% [markdown]
# ---
# ## Question 12
#
# [Task 7.1] In production analyses, why keep job metadata with results?
#
# **A.** Metadata replaces results
# **B.** Metadata is irrelevant
# **C.** Metadata changes outcomes
# **D.** Context (settings/backend/timestamps) is essential for interpretation

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Reproducible interpretation requires contextual metadata.
#
# </details>

# %% [markdown]
# ---
# ## Question 13
#
# [Task 7.2] A subtle but critical bug is:
#
# **A.** Mixing up results from different job ids/session ids
# **B.** Printing status too often
# **C.** Using markdown in notebooks
# **D.** Drawing circuits before run

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Cross-job/session mixups can silently corrupt analysis conclusions.
#
# </details>

# %% [markdown]
# ---
# ## Question 14
#
# [Task 7.1/7.2] What is a good retrieval strategy under intermittent API/network issues?
#
# **A.** Submit duplicate jobs each retry
# **B.** Controlled retry with status re-check and idempotent retrieval logic
# **C.** Ignore failures
# **D.** No retries ever

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Robust clients combine retries with explicit job-id/status checks.
#
# </details>

# %% [markdown]
# ---
# ## Question 15
#
# [Task 7.2] Which is true about monitoring intervals?
#
# **A.** Poll only after completion
# **B.** Poll as fast as possible always
# **C.** Use reasonable polling intervals to balance responsiveness and API load
# **D.** Never poll

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Practical monitoring balances latency and API efficiency.
#
# </details>

# %% [markdown]
# ---
# *End of Section 7 MCQ Practice - Keep pushing toward exam-day readiness.*
