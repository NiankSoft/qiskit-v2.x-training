# %% [markdown]
# # Qiskit Developer Certification Exam
# ## Section 5: Use the sampler primitive
# ### Multiple Choice Questions (MCQ)
#
# ---
# **Instructions:** Each question has 4 options (A-D). Select the best answer. The correct answer with explanation is provided in the collapsed cell below each question.
#
# ---

# %% [markdown]
# ## Question 1
#
# [Task 5.2] What does Sampler fundamentally return for measured circuits?
#
# **A.** Expectation values of observables
# **B.** Unitary decomposition diagnostics
# **C.** Sampled outcomes / distributions from measurements
# **D.** Backend calibration snapshots

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Sampler is for sampling measurement outcomes, not direct expectation-value estimation.
#
# </details>

# %% [markdown]
# ---
# ## Question 2
#
# [Task 5.2] Which statement best contrasts Sampler vs Estimator?
#
# **A.** Sampler cannot run on hardware
# **B.** Estimator always returns counts
# **C.** Sampler requires observables and returns evs
# **D.** Sampler returns sampling data, Estimator returns expectation estimates

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Sampler is distribution-centric; Estimator is observable-expectation-centric.
#
# </details>

# %% [markdown]
# ---
# ## Question 3
#
# [Task 5.2] If shots increase from 1k to 16k, what typically changes?
#
# **A.** Statistical uncertainty in sampled frequencies decreases
# **B.** Measurement basis is redefined
# **C.** Gate semantics change
# **D.** Backend coupling map changes

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Higher shots reduce sampling variance in estimated frequencies.
#
# </details>

# %% [markdown]
# ---
# ## Question 4
#
# [Task 5.2] In modern primitive APIs, a common source of mistakes is confusing:
#
# **A.** Qubit indices and classical bits only
# **B.** Per-run settings vs per-PUB settings
# **C.** Backend names and provider names
# **D.** Quantum and classical registers

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Many exam traps target precedence between global/run-level and per-input configuration.
#
# </details>

# %% [markdown]
# ---
# ## Question 5
#
# [Task 5.2] Which result-access mindset is safest for multi-input runs?
#
# **A.** Only parse logs
# **B.** Use transpiler metadata as final output
# **C.** Treat results as structured per submitted input block
# **D.** Assume one flat dictionary always

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Sampler outputs are structured; robust code indexes by submission/result blocks.
#
# </details>

# %% [markdown]
# ---
# ## Question 6
#
# [Task 5.1] Why can twirling be useful in sampling workflows?
#
# **A.** It forces deterministic bitstrings
# **B.** It guarantees exact noiseless results
# **C.** It removes need for transpilation
# **D.** It can convert coherent error signatures into more stochastic-like behavior

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Twirling is an error-shaping strategy, not a guarantee of perfect accuracy.
#
# </details>

# %% [markdown]
# ---
# ## Question 7
#
# [Task 5.1] Which is the most exam-relevant tradeoff statement?
#
# **A.** Robustness options can improve quality but may increase runtime/cost
# **B.** Robustness options are always free
# **C.** Shots and options are independent concepts
# **D.** Twirling always reduces variance

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Certification questions often test understanding of quality-cost tradeoffs.
#
# </details>

# %% [markdown]
# ---
# ## Question 8
#
# [Task 5.1] If option defaults and run-time values conflict, what is usually expected?
#
# **A.** Backend silently rejects all options
# **B.** More specific run/PUB settings typically override broader defaults
# **C.** All settings are averaged
# **D.** Defaults always win

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Specificity precedence is a recurring practical and exam concept.
#
# </details>

# %% [markdown]
# ---
# ## Question 9
#
# [Task 5.1] Which is a reliable configuration approach in practice?
#
# **A.** Copy Estimator settings blindly
# **B.** Set everything to max by default
# **C.** Tune shots + options to algorithm tolerance and budget
# **D.** Never use options

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Sampler tuning should be goal-driven and resource-aware.
#
# </details>

# %% [markdown]
# ---
# ## Question 10
#
# [Task 5.2] A common trap: interpreting Sampler output as exact probabilities. Correct view?
#
# **A.** Always exact by definition
# **B.** Equivalent to statevector amplitudes
# **C.** Independent of shot count
# **D.** Finite-shot estimates with sampling error unless idealized/infinite

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Sampler outputs are empirical estimates unless in idealized simulation settings.
#
# </details>

# %% [markdown]
# ---
# ## Question 11
#
# [Task 5.2] If a circuit has no measurements, sampler behavior is best described as:
#
# **A.** Measurement outcomes are undefined without a measurement mapping
# **B.** Equivalent to estimator
# **C.** Automatically inserts observables
# **D.** Always valid and meaningful bitstring output

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Sampler semantics revolve around measured outcomes; measurement mapping matters.
#
# </details>

# %% [markdown]
# ---
# ## Question 12
#
# [Task 5.1] Which statement about dynamical decoupling (DD) is correct?
#
# **A.** DD only works for classical simulators
# **B.** DD is an execution/noise-handling strategy and may affect runtime overhead
# **C.** DD changes circuit algorithm semantics by definition
# **D.** DD replaces shot settings

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# DD is an execution strategy for noise behavior, with practical overhead considerations.
#
# </details>

# %% [markdown]
# ---
# ## Question 13
#
# [Task 5.2] When comparing two sampler runs, best practice is to:
#
# **A.** Compare only most frequent bitstring
# **B.** Ignore metadata
# **C.** Use same or controlled shot settings and inspect distribution differences
# **D.** Assume any difference is backend bug

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Fair comparisons require controlled settings and distribution-level analysis.
#
# </details>

# %% [markdown]
# ---
# ## Question 14
#
# [Task 5.1/5.2] Which statement is true?
#
# **A.** Sampler cannot handle parameterized circuits
# **B.** Sampler always returns one scalar
# **C.** Sampler output format is unrelated to primitive input structure
# **D.** Input structure and parameter broadcasting affect output organization

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Input payload structure drives how outputs are grouped and interpreted.
#
# </details>

# %% [markdown]
# ---
# ## Question 15
#
# [Task 5.2] Why is Sampler a good fit for classification-like readout tasks?
#
# **A.** It directly estimates outcome probabilities/frequencies
# **B.** It replaces transpilation
# **C.** It gives direct ev gradients
# **D.** It avoids hardware queueing

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Sampler directly provides measurement statistics that such tasks consume.
#
# </details>

# %% [markdown]
# ---
# *End of Section 5 MCQ Practice - Keep pushing toward exam-day readiness.*
