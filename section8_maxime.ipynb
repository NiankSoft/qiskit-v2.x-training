# %% [markdown]
# # Qiskit Developer Certification Exam
# ## Section 8: Operate with OpenQASM
# ### Multiple Choice Questions (MCQ)
#
# ---
# **Instructions:** Each question has 4 options (A-D). Select the best answer. The correct answer with explanation is provided in the collapsed cell below each question.
#
# ---

# %% [markdown]
# ## Question 1
#
# [Task 8.1] Which API exports a circuit to OpenQASM 3 text in Qiskit?
#
# **A.** `qc.qasm3()`
# **B.** `qiskit.qasm3.dumps(qc)`
# **C.** `qiskit.qasm.dumps(qc)`
# **D.** `qc.to_qasm3_text()`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# `qiskit.qasm3.dumps` is the canonical QASM3 text exporter.
#
# </details>

# %% [markdown]
# ---
# ## Question 2
#
# [Task 8.1] Which statement about OpenQASM 3 classical typing is correct?
#
# **A.** Only float arrays exist
# **B.** Types are comments only
# **C.** It supports typed classical constructs (bit/int/uint/angle, etc.)
# **D.** No classical typing exists

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# OpenQASM 3 adds richer typed classical language features.
#
# </details>

# %% [markdown]
# ---
# ## Question 3
#
# [Task 8.2] A key semantic distinction of OpenQASM 3 vs 2 is:
#
# **A.** No interoperability
# **B.** No measurements
# **C.** No quantum gates
# **D.** Richer control-flow and classical semantics

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# OpenQASM 3 extends program semantics beyond OpenQASM 2's simpler model.
#
# </details>

# %% [markdown]
# ---
# ## Question 4
#
# [Task 8.2] Why is semantic understanding exam-critical?
#
# **A.** Correct behavior depends on language semantics, not just syntax shape
# **B.** Syntax alone determines runtime behavior
# **C.** Semantics are ignored by compilers
# **D.** Semantics only matter for REST

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Many traps involve syntactically valid but semantically different constructs.
#
# </details>

# %% [markdown]
# ---
# ## Question 5
#
# [Task 8.3] Which interop statement is accurate?
#
# **A.** Round-trip is always exact for all constructs
# **B.** Interop exists, but round-trip fidelity may depend on feature support
# **C.** Interop requires non-Python tooling only
# **D.** QASM2/QASM3 interop is impossible

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Interop is supported with practical limitations for unsupported constructs.
#
# </details>

# %% [markdown]
# ---
# ## Question 6
#
# [Task 8.3] If loader/parser meets unsupported OpenQASM feature, likely outcome is:
#
# **A.** Backend hardware reset
# **B.** Silent automatic fallback always
# **C.** Import/parse failure
# **D.** Guaranteed equivalent rewrite

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Unsupported features typically fail at parse/import stage.
#
# </details>

# %% [markdown]
# ---
# ## Question 7
#
# [Task 8.3] Common workflow where supported:
#
# **A.** `qasm2.dumps -> transpile -> histogram`
# **B.** `backend.run -> dumps only`
# **C.** `loads` requires pulse schedule
# **D.** `QuantumCircuit -> qasm3.dumps -> qasm3.loads`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# QASM3 export/import APIs form a direct conversion workflow.
#
# </details>

# %% [markdown]
# ---
# ## Question 8
#
# [Task 8.4] Which HTTP method is typically used for creating/submitting Runtime jobs?
#
# **A.** POST
# **B.** DELETE
# **C.** PATCH
# **D.** GET

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Creation/submission endpoints generally use POST semantics.
#
# </details>

# %% [markdown]
# ---
# ## Question 9
#
# [Task 8.4] Which cancellation endpoint style is typically expected?
#
# **A.** `DELETE /v1/jobs/cancel/{id}`
# **B.** `POST /v1/jobs/{id}/cancel`
# **C.** `GET /v1/jobs/{id}/cancel`
# **D.** `PATCH /v1/cancel/{id}`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Cancellation is commonly modeled as an action endpoint on a job resource.
#
# </details>

# %% [markdown]
# ---
# ## Question 10
#
# [Task 8.4] Standard auth header pattern for IBM-style runtime APIs is:
#
# **A.** `Token <value>`
# **B.** `Runtime <token>`
# **C.** `Bearer <token>`
# **D.** `Session <id>`

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Bearer token authentication is the usual pattern.
#
# </details>

# %% [markdown]
# ---
# ## Question 11
#
# [Task 8.4] Why do API versioned paths matter (`/v1/...`)?
#
# **A.** They disable auth requirements
# **B.** They enforce session mode
# **C.** They set backend shots
# **D.** They define contract/version compatibility boundaries

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# Versioned routes communicate stable API contracts over time.
#
# </details>

# %% [markdown]
# ---
# ## Question 12
#
# [Task 8.4] In client polling logic, safest control variable is:
#
# **A.** Job status transitions until terminal state
# **B.** Register names
# **C.** Notebook execution counter
# **D.** Circuit depth

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: A**
#
# **Explanation:**
# Reliable orchestration should follow job lifecycle status transitions.
#
# </details>

# %% [markdown]
# ---
# ## Question 13
#
# [Task 8.1] Which statement is true about OpenQASM 3 includes/gate declarations?
#
# **A.** Includes are forbidden
# **B.** Includes/declarations provide reusable language-level definitions
# **C.** Includes auto-execute jobs
# **D.** Includes replace transpilation

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: B**
#
# **Explanation:**
# Includes and declarations are language constructs for reusable definitions/context.
#
# </details>

# %% [markdown]
# ---
# ## Question 14
#
# [Task 8.2] Measurement in OpenQASM semantics maps quantum data to:
#
# **A.** A pass manager
# **B.** A backend layout
# **C.** Classical data
# **D.** Another qubit

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: C**
#
# **Explanation:**
# Measurement produces classical outcomes.
#
# </details>

# %% [markdown]
# ---
# ## Question 15
#
# [Task 8.1/8.2] Which statement is correct?
#
# **A.** OpenQASM 3 requires hardware-only execution
# **B.** OpenQASM 3 is only a diagram format
# **C.** OpenQASM 3 cannot represent control flow
# **D.** OpenQASM 3 is a language for quantum-classical programs

# %% [markdown]
# <details>
# <summary>Click to reveal Answer & Explanation</summary>
#
# **Correct Answer: D**
#
# **Explanation:**
# It is a full language representation with syntax and semantics.
#
# </details>

# %% [markdown]
# ---
# *End of Section 8 MCQ Practice - Keep pushing toward exam-day readiness.*
